# %% [markdown]
# ### Welcome to the exercise about observational studies! This exercise will be hands on, and you will be able to practise the skills you developed so far!

# %% [markdown]
# ## Propensity score matching
#
# In this exercise, you will apply [propensity score matching](http://www.stewartschultz.com/statistics/books/Design%20of%20observational%20studies.pdf), which we discussed in lecture 6 ("Observational studies"), in order to draw conclusions from an observational study.
#
# > *remark from myself* : The propensity score represents the chance, given the feature of one individual subject, that it receives the treatment. Hence, propensity score matching matches people who had the most similar chance to get the treatment (their features resemble each other very much, if not exactly), yet one received it (1) and the other not (0). This will permit to see if really, the output re78 depends on whether the subject received the treatment or not.
#
# We will work with a by-now classic dataset from Robert LaLonde's study "[Evaluating the Econometric Evaluations of Training Programs](http://people.hbs.edu/nashraf/LaLonde_1986.pdf)" (1986).
# The study investigated the effect of a job training program ("National Supported Work Demonstration") on the real earnings of an individual, a couple of years after completion of the program.
# Your task is to determine the effectiveness of the "treatment" represented by the job training program.

# %% [markdown]
# #### Dataset description
#
# - `treat`: 1 if the subject participated in the job training program, 0 otherwise
# - `age`: the subject's age
# - `educ`: years of education
# - `race`: categorical variable with three possible values: Black, Hispanic, or White
# - `married`: 1 if the subject was married at the time of the training program, 0 otherwise
# - `nodegree`: 1 if the subject has earned no school degree, 0 otherwise
# - `re74`: real earnings in 1974 (pre-treatment)
# - `re75`: real earnings in 1975 (pre-treatment)
# - `re78`: real earnings in 1978 (outcome)

# %% [markdown]
# If you want to deepen your knowledge on propensity scores and observational studies, we highly recommend Rosenbaum's excellent book on the ["Design of Observational Studies"](http://www.stewartschultz.com/statistics/books/Design%20of%20observational%20studies.pdf). Even just reading the first chapter (18 pages) will help you a lot.

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
# %matplotlib inline

data_folder = './data/'
df = pd.read_csv(data_folder + 'lalonde.csv')

# %%
df.sample(10)
# Out:
#           id  treat  age  educ  black  hispan  married  nodegree        re74  \
# 542  PSID358      0   16     7      0       1        0         1    289.9715
# 523  PSID339      0   26     9      0       1        0         1   1563.4950
# 325  PSID141      0   42     6      0       1        1         1   2425.5720
# 469  PSID285      0   17    10      0       0        0         1      0.0000
# 57     NSW58      1   41     4      1       0        1         1      0.0000
# 527  PSID343      0   36    11      0       0        1         1   1404.7940
# 236   PSID52      0   25    13      0       0        1         0  19259.5900
# 420  PSID236      0   27    12      0       0        1         0   4222.2200
# 212   PSID28      0   39     6      0       1        1         1  13279.9100
# 194   PSID10      0   39    10      0       0        1         1  16767.4100
#
#            re75       re78
# 542      0.0000   7515.717
# 523      0.0000   2862.356
# 325   2832.2900   1907.745
# ...

# %% [markdown]
# ## 1. A naive analysis
#
# Compare the distribution of the outcome variable (`re78`) between the two groups, using plots and numbers.
# To summarize and compare the distributions, you may use the techniques we discussed in lecture 4 ("Describing data") and 3 ("Visualizing data").
#
# What might a naive "researcher" conclude from this superficial analysis?

# %%
import seaborn as sn

sn.lmplot('age', 're78', data=df)
plt.xlabel("Age [y]")
plt.ylabel("Income per Capita [$]")
# Out:
# Text(-9.075000000000003, 0.5, 'Income per Capita [$]')

# %%
# Control group 
plt.scatter(df[df["treat"]==0]["age"],df[df["treat"]==0]["re78"], s=15)
plt.ylim(0,60000)
df[df["treat"]==0][['treat', 'age', 'educ', 're74', 're75', 're78']].mean()


sn.lmplot('age', 're78', data=df[df["treat"]==0])
plt.xlabel("Age [y]")
plt.ylabel("Income per Capita [$]")
# Out:
# Text(-9.075000000000003, 0.5, 'Income per Capita [$]')

# %%
# Treatment group 
plt.scatter(df[df["treat"]==1]["age"],df[df["treat"]==1]["re78"], s=15)
df[df["treat"]==1][['treat', 'age', 'educ', 're74', 're75', 're78']].mean()


sn.lmplot('age', 're78', data=df[df["treat"]==1])
plt.xlabel("Age [y]")
plt.ylabel("Income per Capita [$]")
# Out:
# Text(-9.075000000000003, 0.5, 'Income per Capita [$]')

# %%
from statsmodels.stats import diagnostic
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

mod = smf.ols(formula='re78 ~ treat + age + educ + black + hispan + married + nodegree', data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   re78   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     6.594
# Date:                Fri, 30 Oct 2020   Prob (F-statistic):           1.59e-07
# Time:                        11:35:03   Log-Likelihood:                -6324.3
# No. Observations:                 614   AIC:                         1.266e+04
# Df Residuals:                     606   BIC:                         1.270e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -814.6786   2527.166     -0.322      0.747   -5777.746    4148.388
# ...

# %% [markdown]
# Naively, we could there's a somewhat observable difference in earnings between the "treated" group and the control group, due to the higher average earning for all 3 test years. The amount of educational years doesn't seem to change substancially in average, but when analyzed satistically, p=0.016<0.05 with correlation of 0.17 let's oberserve a small dependency.
#
# The linear regression seems too show an impact of predictors such as education years, black ethnicity and marriage.

# %%
stats.pearsonr(df[df["treat"]==1]['re78'],df[df["treat"]==1]['educ'])
# Out:
# (0.17615883570504848, 0.01645935708286778)

# %%
stats.pearsonr(df[df["treat"]==1]['re78'],df[df["treat"]==1]['age'])
# not significant
# Out:
# (0.08765082448199936, 0.23547049998075312)

# %%
stats.pearsonr(df[df["treat"]==0]['re78'],df[df["treat"]==0]['age'])
# Out:
# (0.11041836288591075, 0.022175667986064344)

# %%
stats.pearsonr(df[df["treat"]==1]['re78'],df[df["treat"]==1]['married'])
# not significant
# Out:
# (0.08684517294591537, 0.2398194861413388)

# %%
stats.pearsonr(df[df["treat"]==0]['re78'],df[df["treat"]==0]['married'])
# small significancy of marriage and age for people of control group, but not for treated group !
# Out:
# (0.1861109800524736, 0.00010554798000788586)

# %%
# Ethnicity
stats.pearsonr(df[df["treat"]==0]['re78'],df[df["treat"]==0]['black'])
#here again, small dependency for control group but not for treated group.
# Out:
# (-0.1475054422338892, 0.002191031529302717)

# %%
# Degree 
stats.pearsonr(df[df["treat"]==0]['re78'],df[df["treat"]==0]['nodegree'])
#negative correlation showing negative impact of not having done any degree, independantly of being treated or not.
# Out:
# (-0.13976612091619206, 0.003723492791712698)

# %% [markdown]
# ## 2. A closer look at the data
#
# You're not naive, of course (and even if you are, you've learned certain things in ADA), so you aren't content with a superficial analysis such as the above.
# You're aware of the dangers of observational studies, so you take a closer look at the data before jumping to conclusions.
#
# For each feature in the dataset, compare its distribution in the treated group with its distribution in the control group, using plots and numbers.
# As above, you may use the techniques we discussed in class for summarizing and comparing the distributions.
#
# What do you observe?
# Describe what your observations mean for the conclusions drawn by the naive "researcher" from his superficial analysis.

# %%
diagnostic.kstest_normal(df[df["treat"]==0]['re78'].values, dist = 'norm')
# both have p<< 0.05, meaning the distrbibution is far from a normal distribution.
# Out:
# C:\Users\julie\anaconda3\lib\site-packages\statsmodels\stats\_lilliefors.py:272: FutureWarning: The default pvalmethod will change from "approx" to "table" after 0.11. The "table" method uses values from a very large simulation and is more accurate.  Explicitly set this parameter to "approx" or "table" to silence this warning
#   warnings.warn(msg, FutureWarning)
# (0.16915713334220528, 1.6972677634174625e-33)

# %% [markdown]
# > From here on, very inspired by corrections

# %%
#to visually analyze all distributions simultaneously
sns.pairplot(df)
#and afterwards, specific pairs will be analyzed

# %%
# Age - treat
df.boxplot(by = 'treat', column='age')

# %%
# Education - treat
df.boxplot(by = 'treat', column='educ')

# %%
# income in the previous year (1974)

ax = sns.distplot(df.loc[df['treat']==1]['re74'], hist=True, label='treated');
ax = sns.distplot(df.loc[df['treat']==0]['re74'], hist=True, label='control')
ax.set(title='Income distribution comparison in 1974',xlabel='Income 1974', ylabel='Income density')
plt.legend()
plt.show()

# %%
# income after the treatment (1978)

ax = sns.distplot(df.loc[df['treat']==1]['re78'], hist=True, label='treated');
ax = sns.distplot(df.loc[df['treat']==0]['re78'], hist=True, label='control')
ax.set(title='Income distribution comparison in 1978',xlabel='Income 1978', ylabel='Income density')
plt.legend()
plt.show()

# %% [markdown]
# As we can observe from this plot, the number of treated members that were unemployed before the training program is quite high. So this might give us an intuition of how much the program helped people to find a job, independently of the income that they got eventually.

# %%
# marriage
group = df.groupby(['treat', 'married'])['married'].count()
group = group.unstack()
group = group.div(group.sum(axis=1), axis=0)
pl = group.plot(kind='bar', figsize=[7,5], rot=0)

# %% [markdown]
# Interesting finding on the kind of people that are taken for this treatment : majoritarly not married.

# %%
# Race
df['white'] = (~df.black.astype(bool) & ~df.hispan.astype(bool)).astype(int)

group = df.groupby(df.treat)['black', 'hispan', 'white'].sum()
group = group.div(group.sum(axis=1), axis=0)
pl = group.plot(kind='bar', figsize=[7,5], rot=0)
# Out:
# <ipython-input-20-720259aedf65>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group = df.groupby(df.treat)['black', 'hispan', 'white'].sum()

# %% [markdown]
# ## 3. A propensity score model
#
# Use logistic regression to estimate propensity scores for all points in the dataset.
# You may use `statsmodels` to fit the logistic regression model and apply it to each data point to obtain propensity scores.
#
# Recall that the propensity score of a data point represents its probability of receiving the treatment, based on its pre-treatment features (in this case, age, education, pre-treatment income, etc.).
# To brush up on propensity scores, you may read chapter 3.3 of the above-cited book by Rosenbaum or [this article](https://drive.google.com/file/d/0B4jctQY-uqhzTlpBaTBJRTJFVFE/view).
#
# Note: you do not need a train/test split here. Train and apply the model on the entire dataset. If you're wondering why this is the right thing to do in this situation, recall that the propensity score model is not used in order to make predictions about unseen data. Its sole purpose is to balance the dataset across treatment groups.
# (See p. 74 of Rosenbaum's book for an explanation why slight overfitting is even good for propensity scores.
# If you want even more information, read [this article](https://drive.google.com/file/d/0B4jctQY-uqhzTlpBaTBJRTJFVFE/view).)

# %%
from statsmodels.stats import diagnostic
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

df['age'] = (df['age'] - df['age'].mean())/df['age'].std()
df['educ'] = (df['educ'] - df['educ'].mean())/df['educ'].std()
df['re74'] = (df['re74'] - df['re74'].mean())/df['re74'].std()
df['re75'] = (df['re75'] - df['re75'].mean())/df['re75'].std()


mod = smf.logit(formula='treat ~ re74 + re75 + age + educ + black + hispan + married  + nodegree', data=df)
res = mod.fit()
print(res.summary())

df['Propensity_score'] = res.predict()
df['Propensity_score']
# Out:
# Optimization terminated successfully.
#          Current function value: 0.397267
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:                  treat   No. Observations:                  614
# Model:                          Logit   Df Residuals:                      605
# Method:                           MLE   Df Model:                            8
# Date:                Fri, 30 Oct 2020   Pseudo R-squ.:                  0.3508
# Time:                        11:56:35   Log-Likelihood:                -243.92
# converged:                       True   LL-Null:                       -375.75
# Covariance Type:            nonrobust   LLR p-value:                 2.194e-52
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.8509      0.350     -8.147      0.000      -3.537      -2.165
# ...

# %% [markdown]
# ## 4. Balancing the dataset via matching
#
# Use the propensity scores to match each data point from the treated group with exactly one data point from the control group, while ensuring that each data point from the control group is matched with at most one data point from the treated group.
# (Hint: you may explore the `networkx` package in Python for predefined matching functions.)
#
# Your matching should maximize the similarity between matched subjects, as captured by their propensity scores.
# In other words, the sum (over all matched pairs) of absolute propensity-score differences between the two matched subjects should be minimized.
#
# This is how networkx library can help you do this. Each possible pair of (treated_person, control_person) is characterized by a similarity. This is how we can initialize a graph, and add an edge for one possible pair. We then need to add an edge for each possible pair.
#     - G = nx.Graph()
#     - G.add_weighted_edges_from([(control_person, treated_person, similarity)])
# Optimal matching is then found with:
#     - matching = nx.max_weight_matching(G)
#
# After matching, you have as many treated as you have control subjects.
# Compare the outcomes (`re78`) between the two groups (treated and control).
#
# Also, compare again the feature-value distributions between the two groups, as you've done in part 2 above, but now only for the matched subjects.
# What do you observe?
# Are you closer to being able to draw valid conclusions now than you were before?

# %%
def get_similarity(propensity_score1, propensity_score2):
    '''Calculate similarity for instances with given propensity scores'''
    return 1-np.abs(propensity_score1-propensity_score2)

# %% [markdown]
# > For this task, we implement the simplest, full optimal matching, and analyse the results.
#
# > In order to perform matching between pairs, a distance/similarity function is needed. Since the library used for the matching (networkx) has a function that maximizes the sum of weights between pairs, it is natural to use a function that measures similarity.
#
# > Wanting to minimize the difference of propensity scores between pairs, we define the similarity function between two instances $x$ and $y$ like:
#
# > $$ similarity(x,y) = 1 - | propensity\_score(x) - propensity\_score(y) |$$
# This function captures the difference in scores like a distance, but since the distance defined like that would always be between 0 and 1, subtracting it from 1 would be a meaningful measure to use for similarity.

# %%
# Separate the treatment and control groups
treatment_df = df[df['treat'] == 1]
control_df = df[df['treat'] == 0]

# Create an empty undirected graph
G = nx.Graph()

# Loop through all the pairs of instances
for control_id, control_row in control_df.iterrows():
    for treatment_id, treatment_row in treatment_df.iterrows():

        # Calculate the similarity 
        similarity = get_similarity(control_row['Propensity_score'],
                                    treatment_row['Propensity_score'])

        # Add an edge between the two instances weighted by the similarity between them
        G.add_weighted_edges_from([(control_id, treatment_id, similarity)])

# Generate and return the maximum weight matching on the generated graph
matching = nx.max_weight_matching(G)
matching
# Out:
# {(0, 253),
#  (3, 484),
#  (4, 510),
#  (5, 453),
#  (8, 243),
#  (10, 199),
#  (11, 565),
#  (16, 570),
#  (18, 461),
#  (19, 341),
#  (24, 595),
#  (25, 355),
#  (26, 371),
#  (29, 383),
#  (32, 408),
#  (33, 519),
#  (35, 444),
#  (36, 295),
#  (40, 603),
#  (41, 459),
#  (42, 582),
#  (43, 435),
#  (44, 588),
#  (48, 569),
#  (52, 573),
#  (56, 479),
#  (57, 474),
#  (58, 215),
#  (64, 334),
#  (65, 564),
#  (68, 263),
#  (72, 230),
#  (73, 283),
#  (80, 190),
#  (81, 275),
#  (82, 526),
#  (83, 357),
#  (84, 373),
#  (87, 415),
#  (88, 322),
#  (90, 594),
#  (91, 590),
#  (96, 437),
#  (97, 422),
#  (100, 391),
#  (101, 541),
#  (102, 607),
#  (104, 583),
#  (105, 342),
#  (106, 517),
#  (108, 268),
#  (110, 518),
#  (112, 404),
#  (113, 372),
#  (114, 389),
#  (115, 574),
#  (116, 311),
#  (120, 514),
#  (124, 340),
#  (128, 364),
#  (129, 343),
#  (130, 477),
#  (132, 492),
#  (133, 367),
#  (136, 293),
#  (137, 318),
#  (138, 386),
#  (141, 535),
#  (144, 513),
# ...

# %%
balanced_df_1 = df.iloc[list(dict(matching).keys())+list(dict(matching).values())]
balanced_df_1
# to get one specific row of dataframe : balanced_df_1.loc[row]
# Out:
#           id  treat       age      educ  black  hispan  married  nodegree  \
# 91     NSW92      1 -1.048780 -0.102244      1       0        0         1
# 556  PSID372      0 -0.745173 -0.482714      1       0        0         1
# 83     NSW84      1 -0.036756  1.039168      1       0        0         0
# 302  PSID118      0 -0.745173  0.278227      1       0        0         1
# 152   NSW153      1 -0.846375 -0.863185      1       0        0         1
# ..       ...    ...       ...       ...    ...     ...      ...       ...
# 279   PSID95      0 -0.239161  0.658697      0       1        1         0
# 342  PSID158      0 -0.947578 -0.102244      1       0        0         1
# 47     NSW48      1 -1.048780 -0.482714      1       0        0         1
# 53     NSW54      1 -0.239161  0.658697      1       0        0         0
# 94     NSW95      1  1.683685  0.278227      1       0        0         1
#
#          re74      re75      re78  white  Propensity_score
# ...

# %%
len(balanced_df_1['married'])
# Out:
# 370

# %%
treated = balanced_df_1.loc[balanced_df_1['treat'] == 1] #People that attained the program
control = balanced_df_1.loc[balanced_df_1['treat'] == 0] #People that didn't attain the program

# %%
ax = sns.distplot(treated['re78'], hist=True, label='treated');
ax = sns.distplot(control['re78'], hist=True, label='control')
ax.set(title='Income distribution comparison in 1978',xlabel='Income 1978', ylabel='Income density')
plt.legend()
plt.show()

# %%
# marriage
group = balanced_df_1.groupby(['treat', 'married'])['married'].count()
group = group.unstack()
group = group.div(group.sum(axis=1), axis=0)
pl = group.plot(kind='bar', figsize=[7,5], rot=0)

# %%
# Race

group = balanced_df_1.groupby(balanced_df_1.treat)['black', 'hispan', 'white'].sum()
group = group.div(group.sum(axis=1), axis=0)
pl = group.plot(kind='bar', figsize=[7,5], rot=0)
# Out:
# <ipython-input-29-cb997f2b0b38>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group = balanced_df_1.groupby(balanced_df_1.treat)['black', 'hispan', 'white'].sum()

# %% [markdown]
# ## 5. Balancing the groups further
#
# Based on your comparison of feature-value distributions from part 4, are you fully satisfied with your matching?
# Would you say your dataset is sufficiently balanced?
# If not, in what ways could the "balanced" dataset you have obtained still not allow you to draw valid conclusions?
#
# Improve your matching by explicitly making sure that you match only subjects that have the same value for the problematic feature.
# Argue with numbers and plots that the two groups (treated and control) are now better balanced than after part 4.

# %% [markdown]
# *My comment :* As can be observed on the plots above, there is the same share of married people in both the treated and control group, however this is not the case for the race type. This remains to be done.

# %%
treatment_df = df[df['treat'] == 1]
control_df = df[df['treat'] == 0]


G = nx.Graph()

for control_id, control_row in control_df.iterrows():
    for treatment_id, treatment_row in treatment_df.iterrows():

        # Adds an edge only if the individuals have the same race
        if (control_row['black'] == treatment_row['black'])\
            and (control_row['hispan'] == treatment_row['hispan']):
            similarity = get_similarity(control_row['Propensity_score'],
                                        treatment_row['Propensity_score'])

            G.add_weighted_edges_from([(control_id, treatment_id, similarity)])

matching = nx.max_weight_matching(G)

# %%
balanced_df_all = df.iloc[list(dict(matching).keys())+list(dict(matching).values())]
balanced_df_all
# Out:
#           id  treat  age  educ  black  hispan  married  nodegree       re74  \
# 556  PSID372      0   20     9      1       0        0         1      0.000
# 361  PSID177      0   19    11      0       0        0         1      0.000
# 302  PSID118      0   20    11      1       0        0         1      0.000
# 225   PSID41      0   22    12      1       0        1         0   9729.719
# 133   NSW134      1   20    11      1       0        0         1  16318.620
# ..       ...    ...  ...   ...    ...     ...      ...       ...        ...
# 293  PSID109      0   21    15      0       0        1         0   6951.479
# 372  PSID188      0   17    10      0       1        0         1      0.000
# 492  PSID308      0   22    11      1       0        1         1   9049.853
# 47     NSW48      1   17     9      1       0        0         1      0.000
# 37     NSW38      1   23    12      1       0        1         0      0.000
#
#          re75      re78
# 556     0.000  6083.800
# ...

# %% [markdown]
# ## 6. A less naive analysis
#
# Compare the outcomes (`re78`) between treated and control subjects, as you've done in part 1, but now only for the matched dataset you've obtained from part 5.
# What do you conclude about the effectiveness of the job training program?

# %%
treated = balanced_df_all.loc[balanced_df_all['treat'] == 1] #People that attained the program
control = balanced_df_all.loc[balanced_df_all['treat'] == 0] #People that didn't attain the program

# %%
treated#treated.re78.describe()
# Out:
#          id  treat  age  educ  black  hispan  married  nodegree       re74  \
# 133  NSW134      1   20    11      1       0        0         1  16318.620
# 1      NSW2      1   22     9      0       1        0         1      0.000
# 145  NSW146      1   19    11      1       0        0         1   2305.026
# 120  NSW121      1   29    14      1       0        0         0      0.000
# 21    NSW22      1   41    14      0       0        0         0      0.000
# ..      ...    ...  ...   ...    ...     ...      ...       ...        ...
# 151  NSW152      1   24    12      1       0        0         0  13765.750
# 28    NSW29      1   17    10      1       0        0         1      0.000
# 10    NSW11      1   19     9      1       0        0         1      0.000
# 47    NSW48      1   17     9      1       0        0         1      0.000
# 37    NSW38      1   23    12      1       0        1         0      0.000
#
#           re75       re78
# 133  1484.9940   6943.342
# ...

# %%
control.re78.describe()
# Out:
# count      116.000000
# mean      5095.456025
# std       6047.014862
# min          0.000000
# 25%          0.000000
# 50%       2256.488500
# 75%       8942.092750
# max      20243.380000
# Name: re78, dtype: float64

# %%
ax = sns.distplot(treated['re78'], hist=True, label='treated');
ax = sns.distplot(control['re78'], hist=True, label='control')
ax.set(title='Income distribution comparison in 1978, after matching',xlabel='Income 1978', ylabel='Income density')
plt.legend()
plt.show()

# %% [markdown]
# Final conclusion: after the propensity score matching, the results change and support the positive effect of the training program. Indeed, when comparing this graph (after matching, that balanced the other features to analyze the income in 1978 dependance to the effectuated (or not) treatment) to the one in task 2, we observe a translation to the right of the blue plots, this time clearly showing that the mean income is higher if the treatment has been done.
